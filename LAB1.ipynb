# %%
import rasterio
from rasterio.plot import show
import rasterio
import geotiff
import tifffile
from PIL import Image
import matplotlib.pyplot as plt
img1 = rasterio.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
show(img1)
img2 = rasterio.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
show(img2)
return plt
# Out:
#   Input In [5]
#     return plt
#     ^
# SyntaxError: 'return' outside function

# %%
#Meta Data About Tiff Images
import rasterio

# Open the GeoTIFF image
with rasterio.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 5600 x 4700
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 4700

# %%
import numpy as np
from PIL import Image
# Open the image
img1 = Image.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
# Convert the image to a NumPy array
img1_array = np.array(img1)
# Calculate image statistics
mean = np.mean(img1_array)
std_dev = np.std(img1_array)
min = np.min(img1_array)
max = np.max(img1_array)
# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Open the image
img2 = Image.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
# Convert the image to a NumPy array
img2_array = np.array(img2)
# Calculate image statistics
mean = np.mean(img2_array)
std_dev = np.std(img2_array)
min = np.min(img2_array)
max = np.max(img2_array)
# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 2530.5342608282676
# Standard Deviation: 2351.9809686732096
# Min: 0
# Max: 65535
# Mean: 2530.5342608282676
# Standard Deviation: 2351.9809686732096
# Min: 0
# Max: 65535

# %%
width, height = img1.size

# Print the results
print("Width:", width)
print("Height:", height)

width, height = img2.size

# Print the results
print("Width:", width)
print("Height:", height)
# Out:
# Width: 5600
# Height: 4700
# Width: 5600
# Height: 4700

# %%
#!pip install opencv-python
# !pip install --upgrade numpy

# %%
from rasterio.plot import show
# import rasterio
import geotiff
import tifffile
# from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
try:
    # Read image from disk.
    img = cv2.imread("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")

    # Get number of pixel horizontally and vertically.
    (height, width) = img.shape[:2]

    # Specify the size of image along with interpolation methods.
    # cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC
    # is used for zooming.
    res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation=cv2.INTER_CUBIC)

    # Write image back to disk.
    cv2.imwrite('result.tiff', res1)

except IOError:
    print('Error while reading files !!!')
# Out:
#   Input In [1]
#     1pip install opencv-python
#      ^
# SyntaxError: invalid syntax

# %%
import rasterio
from rasterio.plot import reshape_as_image
import cv2
try:
    img = rasterio.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
    img_array = img.read()
    img_reshaped = reshape_as_image(img_array)
    height, width = img_array.shape[1], img_array.shape[2]
    new_width = int(width / 2)
    new_height = int(height / 2)
    res = cv2.resize(img_reshaped, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tif', res)  
except IOError:
    print('Error while reading or processing files !!!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import rasterio
#       2 from rasterio.plot import reshape_as_image
# ----> 3 import cv2
#       4 try:
#       5     img = rasterio.open("D:\8 sem\MHR\lab1\ALPSRP245160550-H2.2_UA\HH-ALPSRP245160550-H2.2_UA.tif")
#
# File ~\anaconda3\lib\site-packages\cv2\__init__.py:181, in <module>
#     176             if DEBUG: print("Extra Python code for", submodule, "is loaded")
#     178     if DEBUG: print('OpenCV loader: DONE')
# --> 181 bootstrap()
#
# File ~\anaconda3\lib\site-packages\cv2\__init__.py:175, in bootstrap()
#     172 if DEBUG: print('OpenCV loader: binary extension... OK')
#     174 for submodule in __collect_extra_submodules(DEBUG):
# --> 175     if __load_extra_py_code_for_module("cv2", submodule, DEBUG):
# ...

# %%
# Out:
# Package                       Version
# ----------------------------- --------------------
# affine                        2.4.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# asciitree                     0.3.3
# asgiref                       3.7.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# ...

# %%
# !pip install tensorflow
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %%
from rasterio.plot import show
import geos
import rasterio
import geotiff
import tifffile
import matplotlib.pyplot as plt #For plotting our visualizations
from keras.preprocessing.image import ImageDataGenerator #Keras dataset generator class.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

# %matplotlib inline 
image1 = rasterio.open("D:\\8 sem\\MHR\\lab3\\EALPSRP245160550.tif")
show(image1)
image2 = rasterio.open("D:\\8 sem\\MHR\\lab3\\HH-ALPSRP245160550-H2.2_UA.tif")
show(image2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5 import tifffile
#       6 import matplotlib.pyplot as plt #For plotting our visualizations
# ----> 7 from keras.preprocessing.image import ImageDataGenerator #Keras dataset generator class.
#       8 from numpy import expand_dims
#       9 from keras.preprocessing.image import load_img
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# File ~\anaconda3\lib\site-packages\keras\__internal__\__init__.py:3, in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
# ...

# %%
import keras
import tensorflow as tf

print("Keras version:", keras.__version__)
print("TensorFlow version:", tf.__version__)

# %%
# !pip uninstall tensorflow
#pip install tensorflow
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %%
# !pip uninstall keras
#pip install keras
